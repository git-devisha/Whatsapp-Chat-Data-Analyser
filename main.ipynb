# %%
# !pip install emoji wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: emoji in C:\Users\Devisha\AppData\Roaming\Python\Python313\site-packages (2.15.0)
# Requirement already satisfied: wordcloud in C:\Users\Devisha\AppData\Roaming\Python\Python313\site-packages (1.9.6)
# Requirement already satisfied: numpy>=1.19.3 in C:\Users\Devisha\AppData\Roaming\Python\Python313\site-packages (from wordcloud) (2.1.1)
# Requirement already satisfied: pillow in C:\Users\Devisha\AppData\Roaming\Python\Python313\site-packages (from wordcloud) (11.1.0)
# Requirement already satisfied: matplotlib in C:\Users\Devisha\AppData\Roaming\Python\Python313\site-packages (from wordcloud) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\Devisha\AppData\Roaming\Python\Python313\site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in C:\Users\Devisha\AppData\Roaming\Python\Python313\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\Devisha\AppData\Roaming\Python\Python313\site-packages (from matplotlib->wordcloud) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\Devisha\AppData\Roaming\Python\Python313\site-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Devisha\AppData\Roaming\Python\Python313\site-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in C:\Users\Devisha\AppData\Roaming\Python\Python313\site-packages (from matplotlib->wordcloud) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\Devisha\AppData\Roaming\Python\Python313\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\Devisha\AppData\Roaming\Python\Python313\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)

# %%
import regex
import pandas as pd
import numpy as np

import plotly.express as px
from collections import Counter
import matplotlib.pyplot as plt
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 10
#       8 from os import path
#       9 from PIL import Image
# ---> 10 from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
#
# ModuleNotFoundError: No module named 'wordcloud'
